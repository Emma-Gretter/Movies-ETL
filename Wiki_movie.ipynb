# %%
import json
import pandas as pd
import numpy as np
import re

# %%
file_dir = 'wikipedia-movies.json'

# %%
with open(file_dir, mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# Last 5 records
wiki_movies_raw[-5]
# Out:
# {'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#  'year': 2018,
#  'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#  'title': 'Holmes & Watson',
#  'Directed by': 'Etan Cohen',
#  'Produced by': ['Will Ferrell',
#   'Adam McKay',
#   'Jimmy Miller',
#   'Clayton Townsend'],
#  'Screenplay by': 'Etan Cohen',
#  'Based on': ['Sherlock Holmes',
#   'and',
#   'Dr. Watson',
#   'by',
#   'Sir Arthur Conan Doyle'],
#  'Starring': ['Will Ferrell',
#   'John C. Reilly',
#   'Rebecca Hall',
#   'Rob Brydon',
#   'Steve Coogan',
#   'Ralph Fiennes'],
#  'Music by': 'Mark Mothersbaugh',
#  'Cinematography': 'Oliver Wood',
#  'Edited by': 'Dean Zimmerman',
#  'Productioncompanies ': ['Columbia Pictures',
#   'Gary Sanchez Productions',
#   'Mosaic Media Group',
#   'Mimran Schur Pictures'],
#  'Distributed by': 'Sony Pictures Releasing',
#  'Release date': ['December 25, 2018',
#   '(',
#   '2018-12-25',
#   ')',
#   '(United States)'],
#  'Running time': '90 minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$42 million',
#  'Box office': '$41.9 million'}

# %%
# some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movies_df.columns.to_list()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie]
len(wiki_movies)
# Out:
# 7080

# %%
wiki_df = pd.DataFrame(wiki_movies)

# %%
wiki_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7075    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7076     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7077  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7078  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7079  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7075  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7076  https://www.imdb.com/title/tt6266538/                             Vice
# 7077  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7078  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7079  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7075          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7076          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7077          Mimi Leder                                     Robert W. Cort
# 7078        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7079         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7075                                  Etan Cohen                          NaN
# 7076                                         NaN                          NaN
# 7077                                         NaN                          NaN
# 7078                                         NaN                          NaN
# 7079                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7075  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7076                                                NaN
# 7077                                                NaN
# 7078                                                NaN
# 7079                                                NaN
#
#                                                Starring  ... Hepburn  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN
# ...                                                 ...  ...     ...
# 7075  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...     NaN
# 7076  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...     NaN
# 7077  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...     NaN
# 7078  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...     NaN
# 7079  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 0          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 1          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 2          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 3          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 4          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# ...        ...       ...     ...     ...    ...       ...     ...    ...
# 7075       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7076       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7077       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7078       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7079       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 7075    NaN
# 7076    NaN
# 7077    NaN
# 7078    NaN
# 7079    NaN
#
# [7080 rows x 78 columns]

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles)>0:
        movie['alt_titles']=alt_titles
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
        
    return movie

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url    year  \
# 7060  https://en.wikipedia.org/wiki/The_Insult_(film)  2018.0
# 7293   https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
#
#                                   imdb_link       title    Directed by  \
# 7060  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7293  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 7060  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7293                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 7060                                                NaN
# 7293  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 7060                                                NaN      NaN
# 7293  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring  ... Predecessor  \
# 7060                       [Adel Karam, Kamel El Basha]  ...         NaN
# 7293  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 7060      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7293      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 7060              NaN    NaN
# 7293              NaN    NaN
#
# [2 rows x 193 columns]

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
#  'Founder',
#  'Founders',
#  'French',
#  'Full name',
#  'Gender',
#  'Genre',
#  'Genre(s)',
#  'Genres',
#  'Gwoyeu Romatzyh',
#  'Hangul',
#  'Hanyu Pinyin',
#  'Headquarters',
#  'Hebrew',
#  'Height',
#  'Hepburn',
#  'Hokkien POJ',
#  'IPA',
#  'ISBN',
#  'Illustrator',
#  'Industry',
#  'Instruments',
#  'Japanese',
#  'Jyutping',
#  'Key people',
#  'LC Class',
#  'Label',
#  'Labels',
#  'Language',
#  'Length',
#  'Literal meaning',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Media type',
#  'Mode(s)',
#  'Music',
#  'Music by',
#  'Name',
#  'Narrated by',
#  'Nationality',
#  'No. of episodes',
#  'No. of seasons',
#  'Novel(s)',
#  'Number of employees',
#  'OCLC',
#  'Occupation',
#  'Opening date',
#  'Opening theme',
#  'Operating income',
#  'Original language',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Original work',
#  'Other names',
#  'Owner',
#  'Pages',
#  'Parent',
#  'Parent(s)',
#  'Picture format',
#  'Place premiered',
#  'Platform(s)',
#  'Polish',
#  'Portrayed by',
#  'Preceded by',
#  'Predecessor',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Products',
#  'Programmer(s)',
#  'Publication date',
#  'Published',
#  'Published in English',
#  'Publisher',
#  'Publisher(s)',
#  'Recorded',
#  'Relatives',
#  'Release',
#  'Release date',
#  'Release(s)',
#  'Released',
#  'Replaced',
#  'Replaced by',
#  'Resting place',
#  'Revenue',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Seasons',
#  'Series',
#  'Services',
#  'Set in',
#  'Setting',
#  'Simplified',
#  'Simplified Chinese',
#  'Species',
#  'Spouse(s)',
#  'Starring',
#  'Status',
#  'Story by',
#  'Subject',
#  'Subsidiaries',
#  'Suggested by',
#  'Television series',
#  'Text',
#  'Theme music composer',
#  'Total assets',
#  'Traditional',
#  'Traditional Chinese',
#  'Transcriptions',
#  'Type',
#  'Venue',
#  'Voices of',
#  'Wade–Giles',
#  'Website',
#  'Writer(s)',
#  'Written by',
#  'Yale Romanization',
#  'Years active',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
clean_movie(wiki_movies_df)
# Out:
# {'url': 0       https://en.wikipedia.org/wiki/The_Adventures_o...
#  1       https://en.wikipedia.org/wiki/After_Dark,_My_S...
#  2        https://en.wikipedia.org/wiki/Air_America_(film)
#  3         https://en.wikipedia.org/wiki/Alice_(1990_film)
#  4           https://en.wikipedia.org/wiki/Almost_an_Angel
#                                ...
#  7306      https://en.wikipedia.org/wiki/Holmes_%26_Watson
#  7307       https://en.wikipedia.org/wiki/Vice_(2018_film)
#  7308    https://en.wikipedia.org/wiki/On_the_Basis_of_Sex
#  7309    https://en.wikipedia.org/wiki/Destroyer_(2018_...
#  7310    https://en.wikipedia.org/wiki/Black_Mirror:_Ba...
#  Name: url, Length: 7311, dtype: object,
#  'year': 0       1990.0
#  1       1990.0
#  2       1990.0
#  3       1990.0
#  4       1990.0
#           ...
#  7306    2018.0
#  7307    2018.0
#  7308    2018.0
#  7309    2018.0
#  7310    2018.0
#  Name: year, Length: 7311, dtype: float64,
#  'imdb_link': 0       https://www.imdb.com/title/tt0098987/
#  1       https://www.imdb.com/title/tt0098994/
#  2       https://www.imdb.com/title/tt0099005/
#  3       https://www.imdb.com/title/tt0099012/
#  4       https://www.imdb.com/title/tt0099018/
#                          ...
#  7306    https://www.imdb.com/title/tt1255919/
#  7307    https://www.imdb.com/title/tt6266538/
#  7308    https://www.imdb.com/title/tt4669788/
#  7309    https://www.imdb.com/title/tt7137380/
#  7310    https://www.imdb.com/title/tt9495224/
#  Name: imdb_link, Length: 7311, dtype: object,
#  'title': 0       The Adventures of Ford Fairlane
#  1                  After Dark, My Sweet
#  2                           Air America
#  3                                 Alice
#  4                       Almost an Angel
#                       ...
#  7306                    Holmes & Watson
#  7307                               Vice
#  7308                On the Basis of Sex
#  7309                          Destroyer
#  7310                       Bandersnatch
#  Name: title, Length: 7311, dtype: object,
#  'Directed by': 0             Renny Harlin
#  1              James Foley
#  2       Roger Spottiswoode
#  3              Woody Allen
#  4             John Cornell
#                 ...
#  7306            Etan Cohen
#  7307            Adam McKay
#  7308            Mimi Leder
#  7309          Karyn Kusama
#  7310           David Slade
#  Name: Directed by, Length: 7311, dtype: object,
#  'Produced by': 0                              [Steve Perry, Joel Silver]
#  1                             [Ric Kidney, Robert Redlin]
#  2                                          Daniel Melnick
#  3                                         Robert Greenhut
#  4                                            John Cornell
#                                ...
#  7306    [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
#  7307    [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
#  7308                                       Robert W. Cort
#  7309               [Fred Berger, Phil Hay, Matt Manfredi]
#  7310                                       Russell McLean
#  Name: Produced by, Length: 7311, dtype: object,
#  'Screenplay by': 0       [David Arnott, James Cappe, Daniel Waters]
#  1                     [James Foley, Robert Redlin]
#  2                       [John Eskow, Richard Rush]
#  3                                              NaN
#  4                                              NaN
#                             ...
#  7306                                    Etan Cohen
#  7307                                           NaN
#  7308                                           NaN
#  7309                                           NaN
#  7310                                           NaN
#  Name: Screenplay by, Length: 7311, dtype: object,
#  'Story by': 0       [David Arnott, James Cappe]
#  1                               NaN
#  2                               NaN
#  3                               NaN
#  4                               NaN
#                     ...
#  7306                            NaN
#  7307                            NaN
#  7308                            NaN
#  7309                            NaN
#  7310                            NaN
#  Name: Story by, Length: 7311, dtype: object,
#  'Based on': 0                             [Characters, by Rex Weiner]
#  1       [the novel, After Dark, My Sweet, by, Jim Thom...
#  2                  [Air America, by, Christopher Robbins]
#  3                                                     NaN
#  4                                                     NaN
#                                ...
#  7306    [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
#  7307                                                  NaN
#  7308                                                  NaN
#  7309                                                  NaN
#  7310                                                  NaN
#  Name: Based on, Length: 7311, dtype: object,
#  'Starring': 0       [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
#  1       [Jason Patric, Rachel Ward, Bruce Dern, George...
#  2       [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
#  3       [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
#  4             [Paul Hogan, Elias Koteas, Linda Kozlowski]
#                                ...
#  7306    [Will Ferrell, John C. Reilly, Rebecca Hall, R...
#  7307    [Christian Bale, Amy Adams, Steve Carell, Sam ...
#  7308    [Felicity Jones, Armie Hammer, Justin Theroux,...
#  7309    [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
#  7310    [Fionn Whitehead, Will Poulter, Craig Parkinso...
#  Name: Starring, Length: 7311, dtype: object,
#  'Narrated by': 0       Andrew "Dice" Clay
#  1                      NaN
#  2                      NaN
#  3                      NaN
#  4                      NaN
#                 ...
#  7306                   NaN
#  7307                   NaN
#  7308                   NaN
#  7309                   NaN
#  7310                   NaN
#  Name: Narrated by, Length: 7311, dtype: object,
#  'Music by': 0       [Cliff Eidelman, Yello]
#  1                 Maurice Jarre
#  2                 Charles Gross
#  3                           NaN
#  4                 Maurice Jarre
#                   ...
#  7306          Mark Mothersbaugh
#  7307           Nicholas Britell
#  7308              Mychael Danna
#  7309           Theodore Shapiro
#  7310             Brian Reitzell
#  Name: Music by, Length: 7311, dtype: object,
#  'Cinematography': 0                         Oliver Wood
#  1                        Mark Plummer
#  2                       Roger Deakins
#  3                      Carlo Di Palma
#  4                        Russell Boyd
#                      ...
#  7306                      Oliver Wood
#  7307                     Greig Fraser
#  7308                    Michael Grady
#  7309                   Julie Kirkwood
#  7310    [Aaron Morton, Jake Polonsky]
#  Name: Cinematography, Length: 7311, dtype: object,
#  'Edited by': 0                      Michael Tronick
#  1                      Howard E. Smith
#  2       [John Bloom, Lois Freeman-Fox]
#  3                       Susan E. Morse
#  4                         David Stiven
#                       ...
#  7306                    Dean Zimmerman
#  7307                       Hank Corwin
#  7308                   Michelle Tesoro
#  7309                     Plummy Tucker
#  7310                       Tony Kearns
#  Name: Edited by, Length: 7311, dtype: object,
#  'Productioncompany ': 0                                         Silver Pictures
#  1                                         Avenue Pictures
#  2                   [Carolco Pictures, IndieProd Company]
#  3                                                     NaN
#  4                                                     NaN
#                                ...
#  7306                                                  NaN
#  7307    [Plan B Entertainment, Gary Sanchez Production...
#  7308                                                  NaN
#  7309    [30West, Automatik Entertainment, Annapurna Pi...
#  7310                         [House of Tomorrow, Netflix]
#  Name: Productioncompany , Length: 7311, dtype: object,
#  'Distributed by': 0              20th Century Fox
#  1               Avenue Pictures
#  2              TriStar Pictures
#  3                Orion Pictures
#  4            Paramount Pictures
#                   ...
#  7306    Sony Pictures Releasing
#  7307           Mirror Releasing
#  7308             Focus Features
#  7309           Mirror Releasing
#  7310                    Netflix
#  Name: Distributed by, Length: 7311, dtype: object,
#  'Release date': 0                       [July 11, 1990, (, 1990-07-11, )]
#  1       [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
#  2                     [August 10, 1990, (, 1990-08-10, )]
#  3                   [December 25, 1990, (, 1990-12-25, )]
#  4                                       December 19, 1990
#                                ...
#  7306    [December 25, 2018, (, 2018-12-25, ), (United ...
#  7307    [December 11, 2018, (, 2018-12-11, ), (, Samue...
#  7308    [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
#  7309    [August 31, 2018, (, 2018-08-31, ), (, Telluri...
#  7310                 [28 December 2018, (, 2018-12-28, )]
#  Name: Release date, Length: 7311, dtype: object,
#  'Running time': 0                                 102 minutes
#  1                                 114 minutes
#  2                                 113 minutes
#  3                                 106 minutes
#  4                                  95 minutes
#                          ...
#  7306                               90 minutes
#  7307                              132 minutes
#  7308                              120 minutes
#  7309                              123 minutes
#  7310    Variable; 90 minutes for default path
#  Name: Running time, Length: 7311, dtype: object,
#  'Country': 0        United States
#  1        United States
#  2        United States
#  3        United States
#  4                   US
#               ...
#  7306     United States
#  7307     United States
#  7308     United States
#  7309     United States
#  7310    United Kingdom
#  Name: Country, Length: 7311, dtype: object,
#  'Language': 0              English
#  1              English
#  2       [English, Lao]
#  3              English
#  4              English
#               ...
#  7306           English
#  7307           English
#  7308           English
#  7309           English
#  7310           English
#  Name: Language, Length: 7311, dtype: object,
#  'Budget': 0       $20 million
#  1        $6 million
#  2       $35 million
#  3       $12 million
#  4       $25 million
#             ...
#  7306    $42 million
#  7307    $60 million
#  7308    $20 million
#  7309     $9 million
#  7310            NaN
#  Name: Budget, Length: 7311, dtype: object,
#  'Box office': 0          $21.4 million
#  1           $2.7 million
#  2            $57,718,089
#  3             $7,331,647
#  4       $6,939,946 (USA)
#                ...
#  7306       $41.9 million
#  7307       $76.1 million
#  7308       $38.4 million
#  7309        $5.5 million
#  7310                 NaN
#  Name: Box office, Length: 7311, dtype: object,
#  'Written by': 0                             NaN
#  1                             NaN
#  2                             NaN
#  3                     Woody Allen
#  4                      Paul Hogan
#                    ...
#  7306                          NaN
#  7307                   Adam McKay
#  7308            Daniel Stiepleman
#  7309    [Phil Hay, Matt Manfredi]
#  7310              Charlie Brooker
#  Name: Written by, Length: 7311, dtype: object,
#  'Genre': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Genre, Length: 7311, dtype: object,
#  'Theme music composer': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Theme music composer, Length: 7311, dtype: object,
#  'Country of origin': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Country of origin, Length: 7311, dtype: object,
#  'Original language(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Original language(s), Length: 7311, dtype: object,
#  'Producer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Producer(s), Length: 7311, dtype: object,
#  'Editor(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Editor(s), Length: 7311, dtype: object,
#  'Production company(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Production company(s), Length: 7311, dtype: object,
#  'Original network': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Original network, Length: 7311, dtype: object,
#  'Original release': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Original release, Length: 7311, dtype: object,
#  'Productioncompanies ': 0                                                     NaN
#  1                                                     NaN
#  2                                                     NaN
#  3                                                     NaN
#  4                                                     NaN
#                                ...
#  7306    [Columbia Pictures, Gary Sanchez Productions, ...
#  7307                                                  NaN
#  7308    [Focus Features, [1], Participant Media, [1], ...
#  7309                                                  NaN
#  7310                                                  NaN
#  Name: Productioncompanies , Length: 7311, dtype: object,
#  'Executive producer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Executive producer(s), Length: 7311, dtype: object,
#  'Production location(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Production location(s), Length: 7311, dtype: object,
#  'Distributor': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Distributor, Length: 7311, dtype: object,
#  'Picture format': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Picture format, Length: 7311, dtype: object,
#  'Audio format': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Audio format, Length: 7311, dtype: object,
#  'Voices of': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Voices of, Length: 7311, dtype: object,
#  'Followed by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Followed by, Length: 7311, dtype: object,
#  'Composer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Composer(s), Length: 7311, dtype: object,
#  'Created by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Created by, Length: 7311, dtype: object,
#  'Opening theme': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Opening theme, Length: 7311, dtype: object,
#  'No. of episodes': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: No. of episodes, Length: 7311, dtype: object,
#  'Preceded by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Preceded by, Length: 7311, dtype: object,
#  'Author': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Author, Length: 7311, dtype: object,
#  'Publisher': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Publisher, Length: 7311, dtype: object,
#  'Publication date': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Publication date, Length: 7311, dtype: object,
#  'Media type': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Media type, Length: 7311, dtype: object,
#  'Pages': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Pages, Length: 7311, dtype: object,
#  'ISBN': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: ISBN, Length: 7311, dtype: object,
#  'OCLC': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: OCLC, Length: 7311, dtype: object,
#  'LC Class': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: LC Class, Length: 7311, dtype: object,
#  'Cover artist': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Cover artist, Length: 7311, dtype: object,
#  'Series': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Series, Length: 7311, dtype: object,
#  'Set in': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Set in, Length: 7311, dtype: object,
#  'Adaptation by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Adaptation by, Length: 7311, dtype: object,
#  'Suggested by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Suggested by, Length: 7311, dtype: object,
#  'Biographical data': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Biographical data, Length: 7311, dtype: object,
#  'Born': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Born, Length: 7311, dtype: object,
#  'Died': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Died, Length: 7311, dtype: object,
#  'Resting place': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Resting place, Length: 7311, dtype: object,
#  'Occupation': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Occupation, Length: 7311, dtype: object,
#  'Years active': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Years active, Length: 7311, dtype: object,
#  'Spouse(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Spouse(s), Length: 7311, dtype: object,
#  'Children': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Children, Length: 7311, dtype: object,
#  'Parent(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Parent(s), Length: 7311, dtype: object,
#  'Genres': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Genres, Length: 7311, dtype: object,
#  'Instruments': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Instruments, Length: 7311, dtype: object,
#  'Labels': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Labels, Length: 7311, dtype: object,
#  'Website': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Website, Length: 7311, dtype: object,
#  'Type': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Type, Length: 7311, dtype: object,
#  'Industry': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Industry, Length: 7311, dtype: object,
#  'Fate': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Fate, Length: 7311, dtype: object,
#  'Founded': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Founded, Length: 7311, dtype: object,
#  'Founder': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Founder, Length: 7311, dtype: object,
#  'Headquarters': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Headquarters, Length: 7311, dtype: object,
#  'Parent': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Parent, Length: 7311, dtype: object,
#  'Released': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Released, Length: 7311, dtype: object,
#  'Recorded': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Recorded, Length: 7311, dtype: object,
#  'Venue': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Venue, Length: 7311, dtype: object,
#  'Length': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Length, Length: 7311, dtype: object,
#  'Label': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Label, Length: 7311, dtype: object,
#  'Director': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Director, Length: 7311, dtype: object,
#  'Producer': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Producer, Length: 7311, dtype: object,
#  'Area': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Area, Length: 7311, dtype: object,
#  'Coordinates': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Coordinates, Length: 7311, dtype: object,
#  'Status': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Status, Length: 7311, dtype: object,
#  'Opening date': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Opening date, Length: 7311, dtype: object,
#  'Closing date': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Closing date, Length: 7311, dtype: object,
#  'Replaced': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Replaced, Length: 7311, dtype: object,
#  'Replaced by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Replaced by, Length: 7311, dtype: object,
#  'Name': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Name, Length: 7311, dtype: object,
#  'Attraction type': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Attraction type, Length: 7311, dtype: object,
#  'Music': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Music, Length: 7311, dtype: object,
#  'Duration': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Duration, Length: 7311, dtype: object,
#  'Simplified Chinese': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Simplified Chinese, Length: 7311, dtype: object,
#  'Traditional Chinese': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Traditional Chinese, Length: 7311, dtype: object,
#  'Hanyu Pinyin': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Hanyu Pinyin, Length: 7311, dtype: object,
#  'Literal meaning': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Literal meaning, Length: 7311, dtype: object,
#  'Transcriptions': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Transcriptions, Length: 7311, dtype: object,
#  'Bopomofo': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Bopomofo, Length: 7311, dtype: object,
#  'Gwoyeu Romatzyh': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Gwoyeu Romatzyh, Length: 7311, dtype: object,
#  'Wade–Giles': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Wade–Giles, Length: 7311, dtype: object,
#  'IPA': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: IPA, Length: 7311, dtype: object,
#  'Yale Romanization': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Yale Romanization, Length: 7311, dtype: object,
#  'Jyutping': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Jyutping, Length: 7311, dtype: object,
#  'Hokkien POJ': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Hokkien POJ, Length: 7311, dtype: object,
#  'Animation by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Animation by, Length: 7311, dtype: object,
#  'Color process': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Color process, Length: 7311, dtype: object,
#  'Engine(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Engine(s), Length: 7311, dtype: object,
#  'Genre(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Genre(s), Length: 7311, dtype: object,
#  'Actor control': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Actor control, Length: 7311, dtype: object,
#  'Production company': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Production company, Length: 7311, dtype: object,
#  'Release(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Release(s), Length: 7311, dtype: object,
#  'Format(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Format(s), Length: 7311, dtype: object,
#  'Characters': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Characters, Length: 7311, dtype: object,
#  'Date premiered': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Date premiered, Length: 7311, dtype: object,
#  'Place premiered': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Place premiered, Length: 7311, dtype: object,
#  'Setting': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Setting, Length: 7311, dtype: object,
#  'Original language': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Original language, Length: 7311, dtype: object,
#  'Subject': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Subject, Length: 7311, dtype: object,
#  'Published': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Published, Length: 7311, dtype: object,
#  'Dewey Decimal': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Dewey Decimal, Length: 7311, dtype: object,
#  'Text': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Text, Length: 7311, dtype: object,
#  'Illustrator': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Illustrator, Length: 7311, dtype: object,
#  'Published in English': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Published in English, Length: 7311, dtype: object,
#  'Developed by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Developed by, Length: 7311, dtype: object,
#  'Ending theme': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Ending theme, Length: 7311, dtype: object,
#  'No. of seasons': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: No. of seasons, Length: 7311, dtype: object,
#  'Nationality': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Nationality, Length: 7311, dtype: object,
#  'Portrayed by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Portrayed by, Length: 7311, dtype: object,
#  'Alias': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Alias, Length: 7311, dtype: object,
#  'Species': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Species, Length: 7311, dtype: object,
#  'Gender': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Gender, Length: 7311, dtype: object,
#  'Family': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Family, Length: 7311, dtype: object,
#  'Alma mater': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Alma mater, Length: 7311, dtype: object,
#  'Camera setup': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Camera setup, Length: 7311, dtype: object,
#  'Novel(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Novel(s), Length: 7311, dtype: object,
#  'Comics': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Comics, Length: 7311, dtype: object,
#  'Film(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Film(s), Length: 7311, dtype: object,
#  'Screen story by': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Screen story by, Length: 7311, dtype: object,
#  'Developer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Developer(s), Length: 7311, dtype: object,
#  'Publisher(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Publisher(s), Length: 7311, dtype: object,
#  'Designer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Designer(s), Length: 7311, dtype: object,
#  'Programmer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Programmer(s), Length: 7311, dtype: object,
#  'Artist(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Artist(s), Length: 7311, dtype: object,
#  'Writer(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Writer(s), Length: 7311, dtype: object,
#  'Engine': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Engine, Length: 7311, dtype: object,
#  'Platform(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Platform(s), Length: 7311, dtype: object,
#  'Release': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Release, Length: 7311, dtype: object,
#  'Mode(s)': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Mode(s), Length: 7311, dtype: object,
#  'Original work': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Original work, Length: 7311, dtype: object,
#  'Television series': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Television series, Length: 7311, dtype: object,
#  'Full name': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Full name, Length: 7311, dtype: object,
#  'Height': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Height, Length: 7311, dtype: object,
#  'Seasons': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Seasons, Length: 7311, dtype: object,
#  'Other names': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Other names, Length: 7311, dtype: object,
#  'Relatives': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Relatives, Length: 7311, dtype: object,
#  'Formerly': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Formerly, Length: 7311, dtype: object,
#  'Key people': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Key people, Length: 7311, dtype: object,
#  'Total assets': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Total assets, Length: 7311, dtype: object,
#  'Owner': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Owner, Length: 7311, dtype: object,
#  'Number of employees': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Number of employees, Length: 7311, dtype: object,
#  'Divisions': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Divisions, Length: 7311, dtype: object,
#  'Subsidiaries': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Subsidiaries, Length: 7311, dtype: object,
#  'Predecessor': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Predecessor, Length: 7311, dtype: object,
#  'Founders': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Founders, Length: 7311, dtype: object,
#  'Area served': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Area served, Length: 7311, dtype: object,
#  'Products': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Products, Length: 7311, dtype: object,
#  'Services': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Services, Length: 7311, dtype: object,
#  'Revenue': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Revenue, Length: 7311, dtype: object,
#  'Operating income': 0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#         ...
#  7306    NaN
#  7307    NaN
#  7308    NaN
#  7309    NaN
#  7310    NaN
#  Name: Operating income, Length: 7311, dtype: object,
#  'alt_titles': {'Also known as': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Also known as, Length: 7311, dtype: object,
#   'Arabic': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Arabic, Length: 7311, dtype: object,
#   'Cantonese': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Cantonese, Length: 7311, dtype: object,
#   'Chinese': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Chinese, Length: 7311, dtype: object,
#   'French': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: French, Length: 7311, dtype: object,
#   'Hangul': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Hangul, Length: 7311, dtype: object,
#   'Hebrew': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Hebrew, Length: 7311, dtype: object,
#   'Hepburn': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Hepburn, Length: 7311, dtype: object,
#   'Japanese': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Japanese, Length: 7311, dtype: object,
#   'Literally': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Literally, Length: 7311, dtype: object,
#   'Mandarin': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Mandarin, Length: 7311, dtype: object,
#   'McCune–Reischauer': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: McCune–Reischauer, Length: 7311, dtype: object,
#   'Original title': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Original title, Length: 7311, dtype: object,
#   'Polish': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Polish, Length: 7311, dtype: object,
#   'Revised Romanization': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Revised Romanization, Length: 7311, dtype: object,
#   'Romanized': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Romanized, Length: 7311, dtype: object,
#   'Russian': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Russian, Length: 7311, dtype: object,
#   'Simplified': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Simplified, Length: 7311, dtype: object,
#   'Traditional': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Traditional, Length: 7311, dtype: object,
#   'Yiddish': 0       NaN
#   1       NaN
#   2       NaN
#   3       NaN
#   4       NaN
#          ...
#   7306    NaN
#   7307    NaN
#   7308    NaN
#   7309    NaN
#   7310    NaN
#   Name: Yiddish, Length: 7311, dtype: object}}

# %%
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
clean_movie(wiki_movies_df, change_column_name('Directed by', 'Director'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-cb7ccd8b2d08> in <module>
# ----> 1 clean_movie(wiki_movies_df, change_column_name('Directed by', 'Director'))
#       2
#       3
#
# NameError: name 'change_column_name' is not defined

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Recorded Venue  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...      NaN   NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...      NaN   NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...      NaN   NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...      NaN   NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...      NaN   NaN
#
#   Length Label Director Producer Animation by Color process Screen story by  \
# 0    NaN   NaN      NaN      NaN          NaN           NaN             NaN
# 1    NaN   NaN      NaN      NaN          NaN           NaN             NaN
# 2    NaN   NaN      NaN      NaN          NaN           NaN             NaN
# 3    NaN   NaN      NaN      NaN          NaN           NaN             NaN
# 4    NaN   NaN      NaN      NaN          NaN           NaN             NaN
#
#      imdb_id
# 0  tt0098987
# 1  tt0098994
# 2  tt0099005
# 3  tt0099012
# 4  tt0099018
#
# [5 rows x 57 columns]

# %%
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Directed by', 2],
#  ['Produced by', 360],
#  ['Screenplay by', 4726],
#  ['Story by', 6037],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Music by', 593],
#  ['Cinematography', 691],
#  ['Edited by', 694],
#  ['Productioncompany ', 2532],
#  ['Distributed by', 495],
#  ['Release date', 193],
#  ['Running time', 141],
#  ['Country', 388],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Written by', 2490],
#  ['Genre', 6923],
#  ['Theme music composer', 6966],
#  ['Country of origin', 6881],
#  ['Original language(s)', 6875],
#  ['Producer(s)', 6877],
#  ['Editor(s)', 6887],
#  ['Production company(s)', 6902],
#  ['Original network', 6908],
#  ['Original release', 6874],
#  ['Productioncompanies ', 6310],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Distributor', 6895],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Composer(s)', 7025],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Adaptation by', 7031],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Released', 7031],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Length', 7031],
#  ['Label', 7031],
#  ['Director', 7031],
#  ['Producer', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['Screen story by', 7032],
#  ['imdb_id', 0]]

# %%
[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Productioncompanies ',
#  'imdb_id']

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %%
wiki_movies_df.dtypes
# Out:
# url                     object
# year                     int64
# imdb_link               object
# title                   object
# Directed by             object
# Produced by             object
# Screenplay by           object
# Story by                object
# Based on                object
# Starring                object
# Music by                object
# Cinematography          object
# Edited by               object
# Productioncompany       object
# Distributed by          object
# Release date            object
# Running time            object
# Country                 object
# Language                object
# Budget                  object
# Box office              object
# Written by              object
# Productioncompanies     object
# imdb_id                 object
# dtype: object

# %%
box_office = wiki_movies_df['Box office'].dropna()

# %%
def is_not_a_str(x):
    return type(x) !=str
box_office[box_office.map(is_not_a_str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office[box_office.map(lambda x: type(x) !=str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office = box_office.apply(lambda x: ''.join(x) if type(x) == list else x)

# %%
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'

# %%
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3833

# %%
form_two = r"\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)"

# %%
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1498

# %%
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34      NaN
# 54      NaN
# 74      NaN
# 126     NaN
# 130     NaN
#        ...
# 6980    NaN
# 6994    NaN
# 6995    NaN
# 7015    NaN
# 7048    NaN
# Name: Box office, Length: 154, dtype: object

# %%
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
