# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 34247  False                   NaN      0
# 4188   False                   NaN      0
# 6673   False                   NaN      0
# 44285  False                   NaN      0
# 36418  False                   NaN      0
#
#                                                   genres homepage      id  \
# 34247  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN   56007
# 4188   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   50541
# 6673   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN   71940
# 44285  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...      NaN  117751
# 36418                     [{'id': 27, 'name': 'Horror'}]      NaN  298584
#
#          imdb_id original_language           original_title  \
# 34247  tt0123975                en         Looking For Lola
# 4188   tt0077716                en              Ice Castles
# 6673   tt0106350                en  The Ballad of Little Jo
# 44285  tt2218988                ml          ഉസ്‌താദ്‌ Hotel
# 36418  tt3832096                en              Cabin Fever
#
#                                                 overview  ... release_date  \
# 34247  Looking for Lola is a comical look at the worl...  ...   1997-12-31
# 4188   A young girl is on top of the world until a tr...  ...   1978-12-31
# 6673   Based on a true story, this is the tale of Jos...  ...   1993-08-20
# 44285  Ustad Hotel is a quaint place run by a foodie ...  ...   2012-06-29
# 36418  In this grisly remake of the 2002 horror hit, ...  ...   2016-02-12
#
#       revenue runtime                                   spoken_languages  \
# 34247     0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4188      0.0   108.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6673      0.0   121.0                                                 []
# 44285     0.0   150.0  [{'iso_639_1': 'ta', 'name': 'தமிழ்'}, {'iso_6...
# 36418     0.0    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 34247  Released  He said he was rich...  She said she was riche...
# 4188   Released  The story of a girl who refused to forget she ...
# 6673   Released  In the Wild West, a woman had only two choices...
# 44285  Released                                                NaN
# 36418  Released                  You can't run from what's inside.
#
#                          title  video vote_average vote_count
# 34247         Looking For Lola  False          5.0        1.0
# 4188               Ice Castles  False          6.3       15.0
# 6673   The Ballad of Little Jo  False          5.9        5.0
# 44285              Ustad Hotel  False          7.2       15.0
# 36418              Cabin Fever  False          4.4      113.0
#
# [5 rows x 24 columns]
